# %%
import requests

api_key = "63b07c9e1a3ed0c50d32d18633272d4e"

while True:
    city = input("\nEnter city name (or type 'exit' to quit): ")

    if city.lower() == "exit":
        print("👋 Exiting Weather App. Goodbye!")
        break

    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

    response = requests.get(url)
    data = response.json()

    if data["cod"] != 200:
        print("❌ Invalid city name. Please try again.")
        continue

    # Extract data
    temperature = data["main"]["temp"]
    humidity = data["main"]["humidity"]
    weather = data["weather"][0]["description"]
    wind_speed = data["wind"]["speed"]
    pressure = data["main"]["pressure"]

    # Display output
    print("\n🌦️ WEATHER REPORT")
    print("-" * 35)
    print(f"📍 City: {city}")
    print(f"🌡️ Temperature: {temperature} °C")
    print(f"☁️ Condition: {weather}")
    print(f"💧 Humidity: {humidity}%")
    print(f"🌬️ Wind Speed: {wind_speed} m/s")
    print(f"🔵 Pressure: {pressure} hPa")
    print("-" * 35)
# Out:
# Enter city name (or type 'exit' to quit): kolkata
#
# 🌦️ WEATHER REPORT
# -----------------------------------
# 📍 City: kolkata
# 🌡️ Temperature: 32.08 °C
# ☁️ Condition: clear sky
# 💧 Humidity: 60%
# 🌬️ Wind Speed: 9 m/s
# 🔵 Pressure: 1002 hPa
# -----------------------------------
#
# Enter city name (or type 'exit' to quit): chandannagar
#
# 🌦️ WEATHER REPORT
# -----------------------------------
# 📍 City: chandannagar
# 🌡️ Temperature: 33.58 °C
# ☁️ Condition: few clouds
# 💧 Humidity: 53%
# 🌬️ Wind Speed: 9.9 m/s
# 🔵 Pressure: 1001 hPa
# -----------------------------------
#
# Enter city name (or type 'exit' to quit): delhi
#
# 🌦️ WEATHER REPORT
# -----------------------------------
# 📍 City: delhi
# 🌡️ Temperature: 39.22 °C
# ☁️ Condition: clear sky
# 💧 Humidity: 9%
# 🌬️ Wind Speed: 5.74 m/s
# 🔵 Pressure: 1002 hPa
# -----------------------------------
#
# Enter city name (or type 'exit' to quit): exit
# 👋 Exiting Weather App. Goodbye!
